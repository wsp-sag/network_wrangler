# %% [markdown]
# # Quick Start for Network Wrangler
#
# This notebook should give you a high-level overview of using Wrangler to do the following:
#
# 1. Import a network to wrangler
# 2. Selections - which are used to determine which part of a network to apply a change to
# 3. Changes to attributes
# 4. Write out networks
# 5. Project cards to define selections, changes, and metadata
# 6. Scenarios to manage groups of projects

# %%
import warnings
from pathlib import Path

from network_wrangler import load_roadway_from_dir, write_roadway, load_transit, write_transit
from projectcard import read_card

# %config IPCompleter.greedy=True
import pandas as pd
pd.set_option("display.max_columns", None)
warnings.filterwarnings("ignore")

import logging

logger = logging.getLogger("WranglerLogger")
# set to logging.INFO or DEBUG depending on how much detail you want in the logs
logger.setLevel(logging.INFO)

# %% [markdown]
# # 1. Importing and viewing a network
# ## Locate network folder and files

# %%
STPAUL_DIR = Path.cwd().parent / "examples" / "stpaul"

# %% [markdown]
# ## Roadway Network
#
# The roadway network is comprised of three tables
# 1. Nodes: `nodes_df` with `model_node_id` primary key
# 2. Links: `links_df` with `model_link_id` primary key
#    - Columns `A` and `B` are foreign keys to `nodes_df.model_node_id` representing from-node and to-node respectfully.
#    - Column  `shape_id` is a foreign key to `shapes_df.shape_id`
# 2. Shapes: `shapes_df` with  `shape_id` primary key
#
# ### Network Read
#  - Read in the network specifying where each network component can be found

# %%
road_net = load_roadway_from_dir(STPAUL_DIR)
# Out:
# Skipping field outboundReferenceIds: unsupported OGR type: 5
# Skipping field inboundReferenceIds: unsupported OGR type: 5

# %% [markdown]
# ### Explore the roadway network
#
# * look at first three rows of each network component

# %%
road_rnet.links_df[:3]
# Out:
#                    model_link_id                    osm_link_id  \
# model_link_id_idx
# 224                          224              18214905,18220565
# 280                          280                       18218485
# 281                          281  221685888,221685889,221685893
#
#                                     shstReferenceId  \
# model_link_id_idx
# 224                6a22969708104ae2497244f3d079381d
# 280                bff76735795c148707c774d7f7a0fa6b
# 281                42b68a489b91dd5a1415fb25fb53de65
#
#                                      shstGeometryId  \
# model_link_id_idx
# 224                4a454269d65c6619a2d7e2026295a295
# 280                13e68dc0fe4477f10b9655ebbd5f8435
# 281                9ba14c0a7330177aa938ad0ec43b45f1
#
#                                            shape_id          u           v  \
# model_link_id_idx
# 224                9ef30f714e972087771ed705654fd1f5  493882040   187879468
# 280                2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  493882338   493882339
# 281                f6b3bee60aac5786dc35c6d51f7dab43  493882338  2307229054
#
#                       A       B  \
# model_link_id_idx
# 224                3230   52771
# 280                3261    3262
# 281                3261  131209
#
#                                                   locationReferences  \
# model_link_id_idx
# 224                [{'sequence': 1, 'point': [-93.0837695, 44.963...
# 280                [{'sequence': 1, 'point': [-93.0855338, 44.966...
# 281                [{'sequence': 1, 'point': [-93.0855338, 44.966...
#
#                    distance      roadway  \
# model_link_id_idx
# 224                0.050322  residential
# 280                0.070096     tertiary
# 281                0.084513     tertiary
#
#                                                    name ref bridge tunnel  \
# model_link_id_idx
# 224                Arkwright Street,North Rivoli Street
# 280                                  East Cayuga Street
# 281                                  East Cayuga Street        yes
#
#                   width max_speed  bike_facility  drive_access  walk_access  \
# model_link_id_idx
# 224                                            3         False         True
# 280                                            0          True        False
# 281                                            0          True        False
#
#                    bike_access  truck_access  bus_only  rail_only  lanes  \
# model_link_id_idx
# 224                       True         False     False      False      1
# 280                      False          True     False      False      2
# 281                      False          True     False      False      2
#
#                   access  price  trn_priority  ttime_assert  \
# model_link_id_idx
# 224                         0.0             0             0
# 280                         0.0             0             0
# 281                         0.0             0             0
#
#                                                             geometry projects  \
# model_link_id_idx
# 224                LINESTRING (-93.08377 44.96334, -93.08324 44.9...
# 280                LINESTRING (-93.08553 44.96621, -93.08431 44.9...
# 281                LINESTRING (-93.08553 44.96621, -93.08712 44.9...
#
#                    managed ML_projects
# model_link_id_idx
# 224                      0
# 280                      0
# 281                      0

# %%
road_net.nodes_df[:3]
# Out:
#                    model_node_id osm_node_id shstReferenceId  drive_node  \
# model_node_id_idx
# 1924                        1924        1924                           1
# 1925                        1925        1925                           1
# 1930                        1930        1930                           1
#
#                    walk_node  bike_node  bus_only  rail_only  \
# model_node_id_idx
# 1924                       1          1         0          0
# 1925                       1          1         0          0
# 1930                       1          1         0          0
#
#                                      geometry          X          Y projects
# model_node_id_idx
# 1924               POINT (-93.13665 44.96983) -93.136654  44.969831
# 1925               POINT (-93.13713 44.96468) -93.137132  44.964678
# 1930               POINT (-93.14154 44.95373) -93.141544  44.953727

# %%
road_net.shapes_df[:3]
# Out:
#                                                                 id  \
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  4a454269d65c6619a2d7e2026295a295
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  13e68dc0fe4477f10b9655ebbd5f8435
# f6b3bee60aac5786dc35c6d51f7dab43  9ba14c0a7330177aa938ad0ec43b45f1
#
#                                                           shape_id  \
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  9ef30f714e972087771ed705654fd1f5
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  2ac3bd68a0d0a2d5e6c4f7dcfc19a36e
# f6b3bee60aac5786dc35c6d51f7dab43  f6b3bee60aac5786dc35c6d51f7dab43
#
#                                                 fromIntersectionId  \
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  4d0231aa0ebb779f142c2518703ee481
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  b6ee5e5a4adca2f379b20fe7ee7ca77d
# f6b3bee60aac5786dc35c6d51f7dab43  b6ee5e5a4adca2f379b20fe7ee7ca77d
#
#                                                   toIntersectionId  \
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  3654951b676940911fe5021b93c90cc5
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  51013ccb2e52ee1ea83de6d36e4ef268
# f6b3bee60aac5786dc35c6d51f7dab43  863278524c056439c207888e8f09d04e
#
#                                                 forwardReferenceId  \
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  6a22969708104ae2497244f3d079381d
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  bff76735795c148707c774d7f7a0fa6b
# f6b3bee60aac5786dc35c6d51f7dab43  42b68a489b91dd5a1415fb25fb53de65
#
#                                                                            geometry
# shape_id_idx
# 9ef30f714e972087771ed705654fd1f5  LINESTRING (-93.08377 44.96334, -93.08376 44.9...
# 2ac3bd68a0d0a2d5e6c4f7dcfc19a36e  LINESTRING (-93.08553 44.96621, -93.08524 44.9...
# f6b3bee60aac5786dc35c6d51f7dab43  LINESTRING (-93.08553 44.96621, -93.08574 44.9...

# %% [markdown]
# ## Transit Network
#
# Transit network `feed` property has components represent a dataframe for each GTFS file including:
#
#  - `routes` keyed on `route_id`
#  - `stops` keyed on `stop_id`
#  - `trips` keyed on `trip_id`
#  - `stop_times` with foreign keys `trip_id` and `stop_id`
#  - `frequencies` with foreign key `trip_id`
#
# ### Read Network
#
# Specify the path where to find the transit network files

# %%
transit_net = load_transit(STPAUL_DIR)

# %% [markdown]
# ### Explore the transit network
#
# * look at the first few components of each transit network component

# %%
transit_net.feed.routes[:3]
# Out:
#   route_id agency_id route_short_name  \
# 0    3-111         0                3
# 1   16-111         2               16
# 2   21-111         0               21
#
#                                    route_long_name route_desc route_type  \
# 0  U of M - Como Av - Energy Park Dr - Maryland Av       None          3
# 1                           University Av - Midway       None          3
# 2            Uptown - Lake St - Midway - Selby  Av       None          3
#
#                               route_url route_color route_text_color
# 0   http://www.metrotransit.org/route/3        None           000000
# 1  http://www.metrotransit.org/route/16        None           000000
# 2  http://www.metrotransit.org/route/21        None           000000

# %%
transit_net.feed.stops[:3]
# Out:
#    stop_id stop_code                           stop_name    stop_desc  \
# 0     3261      None        Westminster St & Cayuga St W  Near side S
# 1     4219      None       12th St W & John Ireland Blvd  Near side W
# 2     5149      None  Wabasha St & Vision Loss Resources  Near side N
#
#     stop_lat   stop_lon zone_id  \
# 0  44.966288 -93.085602    None
# 1  44.951319 -93.104096    None
# 2  44.936163 -93.086662    None
#
#                                             stop_url location_type  \
# 0  http://www.metrotransit.org/NexTripBadge.aspx?...             0
# 1  http://www.metrotransit.org/NexTripBadge.aspx?...             0
# 2  http://www.metrotransit.org/NexTripBadge.aspx?...             0
#
#   wheelchair_boarding osm_node_id                         node_ssid  \
# 0                   1   493882338  b6ee5e5a4adca2f379b20fe7ee7ca77d
# 1                   1   954746986  9a057e241974a5839b6bf9c805892197
# 2                   1   652245100  55d02fa3aa91908ecba6798814bd9d73
#
#   parent_station stop_id_GTFS projects gtfs_stop_id
# 0           None         None                 53785
# 1           None         None                 56164
# 2           None         None             291,47040

# %%
transit_net.feed.trips[0:3]
# Out:
#   route_id                service_id                            trip_id  \
# 0  452-111  JUN19-MVS-BUS-Weekday-01  14940701-JUN19-MVS-BUS-Weekday-01
# 1    3-111  JUN19-MVS-BUS-Weekday-01  14941148-JUN19-MVS-BUS-Weekday-01
# 2    3-111  JUN19-MVS-BUS-Weekday-01  14941151-JUN19-MVS-BUS-Weekday-01
#
#                                     trip_headsign direction_id block_id  \
# 0            Westbound 452  Express / Minneapolis            1     1874
# 1  Eastbound 3B Como Av/St Paul - Depot/Via Front            0     1018
# 2  Westbound 3B Como-Front/Dwtn Mpls/Target Field            1     1017
#
#   shape_id wheelchair_accessible trip_destination trip_short_name projects  \
# 0  4520004                     1             None            None
# 1    30009                     1             None            None
# 2    30014                     1             None            None
#
#    trip_route_name pub_dir_id rm_block_id
# 0              NaN       None        None
# 1              NaN       None        None
# 2              NaN       None        None

# %%
transit_net.feed.stop_times[:3]
# Out:
#                              trip_id        arrival_time      departure_time  \
# 0  14941148-JUN19-MVS-BUS-Weekday-01                 NaT                 NaT
# 1  14941148-JUN19-MVS-BUS-Weekday-01 2024-10-16 00:01:00 2024-10-16 00:01:00
# 2  14941148-JUN19-MVS-BUS-Weekday-01 2024-10-16 00:01:00 2024-10-16 00:01:00
#
#    stop_sequence pickup_type drop_off_type  stop_distance timepoint  \
# 0             46           0             0            NaN         0
# 1             47           0             0            NaN         0
# 2             48           0             0            NaN         0
#
#    stop_is_skipped  stop_id projects
# 0              NaN    72333
# 1              NaN    83136
# 2              NaN    66544

# %%
transit_net.feed.frequencies[0:3]
# Out:
#                              trip_id  headway_secs          start_time  \
# 0  14940701-JUN19-MVS-BUS-Weekday-01          3600 2024-10-16 06:00:00
# 1  14941148-JUN19-MVS-BUS-Weekday-01           830 2024-10-16 06:00:00
# 2  14941151-JUN19-MVS-BUS-Weekday-01           540 2024-10-16 06:00:00
#
#              end_time projects
# 0 2024-10-16 09:00:00
# 1 2024-10-16 09:00:00
# 2 2024-10-16 09:00:00

# %%
transit_net.feed.shapes[:5]
# Out:
#   shape_id  shape_pt_lat  shape_pt_lon  shape_pt_sequence shape_osm_node_id  \
# 0  4520004     44.923257    -93.067060                 55         507955865
# 1  4520004     44.930632    -93.071166                 56         507951624
# 2  4520004     44.932669    -93.071710                 57         507951633
# 3  4520004     44.939445    -93.075273                 58         507951645
# 4  4520004     44.943056    -93.076998                 59        2548150957
#
#    shape_model_node_id projects
# 0               152495
# 1               151635
# 2               151637
# 3               151641
# 4                23834

# %% [markdown]
# ### Map Transit Network
#
# There are several convenience methods to transit network to create geodataframes to make the transit network straightforward to visualize.
#
# - `transit_net.stops_gdf` Stops from `stops.txt`
# - `shapes_gdf` Consolidate shapes from `shapes.txt`
# - `shape_links_gdf` Individual links from `shapes.txt`
# - `stop_time_links_gdf` Links from `stop_times.txt`
# - `stop_times_points_gdf` Points from `stop_times.txt`

# %%
my_map = transit_net.stops_gdf.explore(
    tooltips=["stop_id","stop_name"],
    color = "purple",
    tiles = "cartodbpositron"
)
transit_net.stop_time_links_gdf.explore(
    tooltips=["trip_id"],
    m = my_map,
    color = "grey",
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_341306313a40e85abdd08961f94bf5df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_341306313a40e85abdd08961f94bf5df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_341306313a40e85abdd08961f94bf5df = L.map(
#                 &quot;map_341306313a40e85abdd08961f94bf5df&quot;,
#                 {
#                     center: [44.952084, -93.1010195],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_341306313a40e85abdd08961f94bf5df);
#
#
#
#
#
#             var tile_layer_741c6706af6c534dd44659f84a17744b = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_741c6706af6c534dd44659f84a17744b.addTo(map_341306313a40e85abdd08961f94bf5df);
#
#
#             map_341306313a40e85abdd08961f94bf5df.fitBounds(
#                 [[44.91961, -93.146419], [44.984558, -93.05562]],
#                 {}
#             );
#
#
#         function geo_json_023168b01ed48341c118018b105ee773_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_023168b01ed48341c118018b105ee773_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_023168b01ed48341c118018b105ee773_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_023168b01ed48341c118018b105ee773_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_023168b01ed48341c118018b105ee773_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_023168b01ed48341c118018b105ee773.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_023168b01ed48341c118018b105ee773_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_023168b01ed48341c118018b105ee773 = L.geoJson(null, {
#                 onEachFeature: geo_json_023168b01ed48341c118018b105ee773_onEachFeature,
#
#                 style: geo_json_023168b01ed48341c118018b105ee773_styler,
#                 pointToLayer: geo_json_023168b01ed48341c118018b105ee773_pointToLayer,
#                 tooltips: [&quot;stop_id&quot;, &quot;stop_name&quot;],
#         });
#
#         function geo_json_023168b01ed48341c118018b105ee773_add (data) {
#             geo_json_023168b01ed48341c118018b105ee773
#                 .addData(data);
#         }
#             geo_json_023168b01ed48341c118018b105ee773_add({&quot;bbox&quot;: [-93.146419,

# %% [markdown]
# **View a routes or a single route**

# %%
selected_route_ids = ["3-111"]
from network_wrangler.transit.feed.stop_times import stop_times_for_route_ids
from network_wrangler.transit.geo import stop_times_to_stop_time_links_gdf
sel_stop_times = stop_times_for_route_ids(transit_net.feed.stop_times, transit_net.feed.trips, selected_route_ids)
sel_stop_times_gdf = stop_times_to_stop_time_links_gdf(sel_stop_times, transit_net.feed.stops)
sel_stop_times_gdf.explore(m=my_map, color="red", tooltips=["trip_id", "stop_id"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_341306313a40e85abdd08961f94bf5df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_341306313a40e85abdd08961f94bf5df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_341306313a40e85abdd08961f94bf5df = L.map(
#                 &quot;map_341306313a40e85abdd08961f94bf5df&quot;,
#                 {
#                     center: [44.952084, -93.1010195],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_341306313a40e85abdd08961f94bf5df);
#
#
#
#
#
#             var tile_layer_741c6706af6c534dd44659f84a17744b = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_741c6706af6c534dd44659f84a17744b.addTo(map_341306313a40e85abdd08961f94bf5df);
#
#
#             map_341306313a40e85abdd08961f94bf5df.fitBounds(
#                 [[44.91961, -93.146419], [44.984558, -93.05562]],
#                 {}
#             );
#
#
#         function geo_json_023168b01ed48341c118018b105ee773_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;purple&quot;, &quot;fillColor&quot;: &quot;purple&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_023168b01ed48341c118018b105ee773_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_023168b01ed48341c118018b105ee773_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_023168b01ed48341c118018b105ee773_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_023168b01ed48341c118018b105ee773_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_023168b01ed48341c118018b105ee773.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_023168b01ed48341c118018b105ee773_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_023168b01ed48341c118018b105ee773 = L.geoJson(null, {
#                 onEachFeature: geo_json_023168b01ed48341c1180

# %% [markdown]
# ## 2. Query Network Features
#
# Most of Network wrangler operates by querying a portion of the network and then making changes to it.
#
# Queries take the form of Python Dictionaries or can be read-in as YAML which is then converted to a python dictionary.
#
# If a query has already been made, it is stored in the network so that it will not take up computing power to find it again.
#
# ### Highway Segment Selection
#
# Highway selections for links have three required components: `links`, `from` and `to`.
#
# - `links` must either have a specified name, or an 'osmid'
# - `from` and `to` must specify some sort of unique identifier which is found in the data structure (AKA, it should return a single node) like `model_node_id` or `osm_node_id`.
#
# If not all the links connecting `from` to `to` have the `name`, wrangler will connect them using as many streets with the correct name as possible.

# %%
easy_selection = {
    "links": {
            "name": ["6th", "Sixth", "sixth"]
    },  # find streets that have one of the various forms of 6th
    "from": {"osm_node_id": "187899923"},  # start searching for segments at this id
    "to": {"osm_node_id": "187942339"},  # end segment at this id
}

# %%
# querying with the selection will return the links that are selected
sel = road_net.get_selection(easy_selection)
display_cols = ["name", "A", "B", "lanes"]
sel.selected_links_df[display_cols]
# Out:
#                                     name       A       B  lanes
# model_link_id_idx
# 2846                     East 6th Street    4758    4806      1
# 2918                     East 6th Street    4806   72303      1
# 78740                    East 5th Street   39430   68608      3
# 96983                    East 5th Street   46665  150855      3
# 134542                   East 5th Street   62145   39430      2
# 148977                   East 5th Street   68608   76167      1
# 157437                   East 6th Street   72303   77072      1
# 165718                   East 5th Street   76167   46665      3
# 167745                   East 6th Street   77072   77073      1
# 336883             North Broadway Street  150855   11188      2
# 381640                   East 6th Street    4759    4758      1
# 383275                                     11090  121374      1
# 383276                                     11094   11090      1
# 383319                                     11188   11094      1
# 395710               Robert Street North   62146   62145      2
# 410086                                    121370    4759      1
# 410088                                    121374  121370      5

# %%
sel.selected_links_df.explore(tiles="cartodbpositron", column = "lanes", cmap = "viridis", tooltip=display_cols)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4354c86113e7aea62529380a0e5aabe5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4354c86113e7aea62529380a0e5aabe5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4354c86113e7aea62529380a0e5aabe5 = L.map(
#                 &quot;map_4354c86113e7aea62529380a0e5aabe5&quot;,
#                 {
#                     center: [44.9530307, -93.08038595],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4354c86113e7aea62529380a0e5aabe5);
#
#
#
#
#
#             var tile_layer_29287c2e1959db86f686519679edfe55 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_29287c2e1959db86f686519679edfe55.addTo(map_4354c86113e7aea62529380a0e5aabe5);
#
#
#             map_4354c86113e7aea62529380a0e5aabe5.fitBounds(
#                 [[44.947435799999994, -93.091634], [44.958625600000005, -93.0691379]],
#                 {}
#             );
#
#
#         function geo_json_33db3d378438a9bc2202ec33e4b3f91b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;8&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;15&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;3&quot;: case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;16&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#3b518b&quot;, &quot;fillColor&quot;: &quot;#3b518b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_33db3d378438a9bc2202ec33e4b3f91b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_33db3d378438a9bc2202ec33e4b3f91b_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_33db3d378438a9bc2202ec33e4b3f91b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_33db3d378438a9bc2202ec33e4b3f91b_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_33db3d378438a9bc2202ec33e4b3f91b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_33db3d378438a9bc2202ec33e4b3f91b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_33db3d378438a9bc2202ec33e4b3f91b = L.geoJson(null, {
#                 onEachFeature: geo_json_33db3d378438a9bc2202ec33e4b3f91b_onEachFeature,
#
#                 style: geo_json_33db3d378438a9bc2202ec33e4b3f91b_styler,

# %% [markdown]
# ### More complex selections
#
# You can also select facilities based on their properties.  This selection is tiered from the name/osmid selection.

# %%
multi_criteria_selection = {
    "links": {
        "name": ["6th", "Sixth", "sixth"],
        "lanes": [2, 3],  # from the initial selection, only select streets with 1 OR 2 lanes
    },
    "from": {"osm_node_id": "187899923"},  # start searching for segments at this id
    "to": {"osm_node_id": "187942339"},  # end segment at this id
}
multi_sel = road_net.get_selection(multi_criteria_selection)
multi_sel.selected_links_df.explore(tiles="cartodbpositron", column = "lanes", cmap = "viridis",tooltip=display_cols)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45ecec879c4ce1c79a0e7635686538bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45ecec879c4ce1c79a0e7635686538bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45ecec879c4ce1c79a0e7635686538bf = L.map(
#                 &quot;map_45ecec879c4ce1c79a0e7635686538bf&quot;,
#                 {
#                     center: [44.949036199999995, -93.0883651],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_45ecec879c4ce1c79a0e7635686538bf);
#
#
#
#
#
#             var tile_layer_747cfa5bec02f6f7e7917e9d12f22839 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_747cfa5bec02f6f7e7917e9d12f22839.addTo(map_45ecec879c4ce1c79a0e7635686538bf);
#
#
#             map_45ecec879c4ce1c79a0e7635686538bf.fitBounds(
#                 [[44.947435799999994, -93.091634], [44.950636599999996, -93.0850962]],
#                 {}
#             );
#
#
#         function geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a6a11eb260cb68aa64b4a2ee3110c96e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a6a11eb260cb68aa64b4a2ee3110c96e = L.geoJson(null, {
#                 onEachFeature: geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_onEachFeature,
#
#                 style: geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_styler,
#                 pointToLayer: geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_pointToLayer,
#         });
#
#         function geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_add (data) {
#             geo_json_a6a11eb260cb68aa64b4a2ee3110c96e
#                 .addData(data);
#         }
#             geo_json_a6a11eb260cb68aa64b4a2ee3110c96e_add({&quot;bbox&quot;: [-93.091634, 44.947435799999994, -93.0850962, 44.950636599999996], &quot;features&quot;: [{&quot;bbox&quot;: [-93.089477, 44.9480786, -93.08811570000002, 44.9487217], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-93.089477, 44.9480786], [-

# %% [markdown]
# ### Transit Selection
#
#
# Transit trip selection can currently happen by querying trips, routes, etc.

# %%
selection_by_trip_prop = {"trip_properties": {"route_id": ["365-111"]}}
selected_trips = transit_net.get_selection(selection_by_trip_prop).selected_trips
transit_net.feed.trips[transit_net.feed.trips.trip_id.isin(selected_trips)]
# Out:
#    route_id                service_id                            trip_id  \
# 35  365-111  JUN19-MVS-BUS-Weekday-01  14947182-JUN19-MVS-BUS-Weekday-01
#
#                             trip_headsign direction_id block_id shape_id  \
# 35  Northbound 365  Express / Minneapolis            0     1844  3650001
#
#    wheelchair_accessible trip_destination trip_short_name projects  \
# 35                     1             None            None
#
#     trip_route_name pub_dir_id rm_block_id
# 35              NaN       None        None

# %%
selection_by_route_prop  = {"route_properties": {"route_short_name": ["3"]}}
selected_trips = transit_net.get_selection(selection_by_route_prop).selected_trips
transit_net.feed.routes[transit_net.feed.trips.trip_id.isin(selected_trips)]
# Out:
#   route_id agency_id route_short_name  \
# 1   16-111         2               16
# 2   21-111         0               21
# 3   53-111         0               53
# 4   62-111         0               62
#
#                                     route_long_name route_desc route_type  \
# 1                            University Av - Midway       None          3
# 2             Uptown - Lake St - Midway - Selby  Av       None          3
# 3         Ltd Stop - Uptown - Lake St - Marshall Av       None          3
# 4  Shoreview - Little Canada - Rice St Signal Hills       None          3
#
#                               route_url route_color route_text_color
# 1  http://www.metrotransit.org/route/16        None           000000
# 2  http://www.metrotransit.org/route/21        None           000000
# 3  http://www.metrotransit.org/route/53        None           000000
# 4  http://www.metrotransit.org/route/62        None           000000

# %% [markdown]
# #### Visualize selection on map
#
# Note that this is a mouthful of code.  I have a todo to write a wrapper around this so that you can easily visualize with an api of something like:  `transit_net.get_selection(simple_transit_selection).plot()`

# %%
from network_wrangler.transit.feed.stop_times import stop_times_for_trip_ids
from network_wrangler.transit.geo import stop_times_to_stop_time_links_gdf
sel_stop_times = stop_times_for_trip_ids(transit_net.feed.stop_times, selected_trips)
sel_stop_times_gdf = stop_times_to_stop_time_links_gdf(sel_stop_times, transit_net.feed.stops)
sel_stop_times_gdf.explore(tiles="cartodbpositron", color="green", tooltips=["trip_id", "stop_id"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d85b2885a77fb2c9b2273574e29d8cf5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d85b2885a77fb2c9b2273574e29d8cf5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d85b2885a77fb2c9b2273574e29d8cf5 = L.map(
#                 &quot;map_d85b2885a77fb2c9b2273574e29d8cf5&quot;,
#                 {
#                     center: [44.957695, -93.1148],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d85b2885a77fb2c9b2273574e29d8cf5);
#
#
#
#
#
#             var tile_layer_edfa86e12c272dc38b2c843dd36c15e1 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_edfa86e12c272dc38b2c843dd36c15e1.addTo(map_d85b2885a77fb2c9b2273574e29d8cf5);
#
#
#             map_d85b2885a77fb2c9b2273574e29d8cf5.fitBounds(
#                 [[44.944982, -93.146359], [44.970408, -93.083241]],
#                 {}
#             );
#
#
#         function geo_json_45e6c6509c30572f9cdac8fb1c013874_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_45e6c6509c30572f9cdac8fb1c013874_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_45e6c6509c30572f9cdac8fb1c013874_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_45e6c6509c30572f9cdac8fb1c013874_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_45e6c6509c30572f9cdac8fb1c013874_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_45e6c6509c30572f9cdac8fb1c013874.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_45e6c6509c30572f9cdac8fb1c013874_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_45e6c6509c30572f9cdac8fb1c013874 = L.geoJson(null, {
#                 onEachFeature: geo_json_45e6c6509c30572f9cdac8fb1c013874_onEachFeature,
#
#                 style: geo_json_45e6c6509c30572f9cdac8fb1c013874_styler,
#                 pointToLayer: geo_json_45e6c6509c30572f9cdac8fb1c013874_pointToLayer,
#                 tooltips: [&quot;trip_id&quot;, &quot;stop_id&quot;],
#         });
#
#         function geo_json_45e6c6509c30572f9cdac8fb1c013874_add (data) {
#             geo_json_45e6c6509c30572f9cdac8fb1c013874
#                 .addData(data);
#         }
#             geo_json_45e6c6509c30572f9cdac8fb1c013874_add({&quot;bbox&quot;: [-93.146359, 44.944982, -93.083241, 44.970408], &quot;features&quot;: [{&quot;bbox&quot;: [-93.106146, 44.951319, -93.104096, 44.952297], &quot;geometry&quot;: {&quot;coordinates&quot;: [[-93.104096, 44.951319], [-93.106146, 44.952297]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;A&quot;: 4219, &quot;A_X&quot;: -93.104096, &quot;A_Y&quot;: 44.951319, &quot;B&quot;: 134498, &quot;B_X&quot;: -93.106146, &quot;B_Y&quot;: 44.952297, &quot;__folium_color&quot;: &quot;green&quot;, &quot;stop_id_x&qu

# %% [markdown]
# # 3. Change Feature Attributes
#
# Changes are made by:
# 1. selecting the features to change
# 2. defining what properties should change and how
#
# Selections are defined by dictionaries containing selection requirements.
#
# ## Highway Feature Change
#
#  - RoadwayNetwork link features are selected by link features, and conditionally start and end points
#  - Additional refinements to the selection can made by specifying additional properties such as `lanes` etc.

# %%
selected_highway = {
    "links": {"ref": ["I 35E"]},
}

# %% [markdown]
# ### Specify Change
#
# Changes are specified by a dictionary.  For highway changes, there should be a list of dictionaries under `properties` where each entity has a `property` and either `set` for an absolute value or `change`  to direct that a value is changed.

# %%
lane_change = {
    "project": "lane_change",
    "roadway_property_change": {
        "facility": selected_highway, 
        "property_changes": {
            "lanes": {"set": 2}
        }
    }
}

# %%
road_net_build = road_net.apply(lane_change)
road_net_build.links_df.loc[road_net_build.links_df.ref == "I 35E", ["ref","lanes","projects"]].head()
# Out:
#                      ref  lanes  \
# model_link_id_idx
# 381412             I 35E      2
# 382547             I 35E      2
# 385471             I 35E      2
# 390634             I 35E      2
# 390975             I 35E      2
#
#                                                            projects
# model_link_id_idx
# 381412             lane_change,lane_change,lane_change,lane_change,
# 382547             lane_change,lane_change,lane_change,lane_change,
# 385471             lane_change,lane_change,lane_change,lane_change,
# 390634             lane_change,lane_change,lane_change,lane_change,
# 390975             lane_change,lane_change,lane_change,lane_change,

# %% [markdown]
# #### You can also increment from the existing value using the field `change`
# And optionally, you can call out what you think the existing value should be so that it fails if it isn't the case.

# %%
lane_change = {
    "project": "lane_change",
    "roadway_property_change": {
        "facility": selected_highway, 
        "property_changes": {
            "lanes": {"change": 4}
        }
    }
}

road_net_build = road_net.apply(lane_change)
road_net_build.links_df.loc[road_net_build.links_df.ref == "I 35E", ["ref","lanes","projects"]].head()
# Out:
#                      ref  lanes  \
# model_link_id_idx
# 381412             I 35E      6
# 382547             I 35E      6
# 385471             I 35E      6
# 390634             I 35E      6
# 390975             I 35E      6
#
#                                                             projects
# model_link_id_idx
# 381412             lane_change,lane_change,lane_change,lane_chang...
# 382547             lane_change,lane_change,lane_change,lane_chang...
# 385471             lane_change,lane_change,lane_change,lane_chang...
# 390634             lane_change,lane_change,lane_change,lane_chang...
# 390975             lane_change,lane_change,lane_change,lane_chang...

# %% [markdown]
# ## Transit Feature Change
#
#
# Transit changes follow the same pattern as highway network changes with a selection and then a change for each project.

# %%
trip_ids = ["14941148-JUN19-MVS-BUS-Weekday-01"]
new_headway = 1600
transit_project = {
    "project": "Bus Frequency Blue1",
    "transit_property_change": {
        "service": {
            "trip_properties": {"trip_id": trip_ids}, 
        },
        "property_changes": {"headway_secs": {"set": new_headway}},
    }
}

# %%
transit_net_build = transit_net.apply(transit_project)
transit_net_build.feed.frequencies.loc[transit_net_build.feed.frequencies.trip_id.isin(trip_ids)]
# Out:
#                              trip_id  headway_secs          start_time  \
# 1  14941148-JUN19-MVS-BUS-Weekday-01          1600 2024-10-16 06:00:00
#
#              end_time              projects
# 1 2024-10-16 09:00:00  Bus Frequency Blue1,

# %% [markdown]
# # 4 - Write out Networks
#
# Networks can be written by calling their respective `write()` method.  If you'd like to output them to other serialization formats, you can do that by using the `file_format` keyword.
#
# Transit file formats: `csv`, `parquet`, `txt`
# Roadway file formats: `geojson`, `shp`, `parquet`
#
# Note that some fields - noteably those with arrays within the field - are not compatible with some serialization formats.

# %%
OUTPATH = Path.cwd()
OUTPATH
# Out:
# PosixPath('/Users/elizabethsall/Documents/GitHub/network_wrangler/notebook')

# %%
write_roadway(road_net, prefix="my_net", out_dir=OUTPATH)

# %%
write_transit(transit_net, out_dir=OUTPATH)

# %% [markdown]
# # 5 - Project cards to document selections, changes, and metadata
#
# The whole property change process above can be more seamless and replicable by using "project cards" which specify  the selection, changes, and project metadata.

# %%
roadway_project_card_file = STPAUL_DIR / "project_cards"/ "road.managed_lane.simple.yml"
roadway_project_card = read_card(roadway_project_card_file)
build_road_net = road_net.apply(roadway_project_card)

# %% [markdown]
# # 6 - Scenarios to manage groups of changes
#
# The Scenario object manages groups of projects defined in project cards.
#
# - Scenarios are initialized by defining a base scenario, which at a minimum specifies the base roadway networks and also may specify a base transit networks and a list of projects that have already been applied.
# - Projects can  be "added" or "queued" to a scenario.
# - Projects are then "applied" or "built" on the scenario using logic about pre-requisites and co-requisites.

# %%
from network_wrangler import create_scenario
projects = [
    STPAUL_DIR/"project_cards"/"road.add_and_delete.yml",
    STPAUL_DIR/"project_cards"/"road.prop_change.time_of_day.yml",
]
my_scenario = create_scenario(
    base_scenario={"road_net": road_net, "transit_net": transit_net},
    project_card_filepath=projects,
)

my_scenario.apply_all_projects()

# note - see how there is a warning because we have deleted a link that had transit running on it.  This should prompt you to either add a transit re-routing change to that project card or apply another project that will remedy this situation.
# Out:
# Base_scenario doesn't contain ['road_net', 'transit_net', 'applied_projects', 'conflicts']
# Creating a deep copy of db object.            This will NOT update any references (e.g. from TransitNetwork)
# No links found matching criteria.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# Timespan is not in increasing order: ['19:00', '6:00'].            End time will be treated as next day.
# ! Transit shape links missing in roadway network:
#             shape_id     A       B
# 1  [710001, 710004]  3261  131209
# Deletion breaks transit shapes:
#            shape_id     A       B
# 1  [710001, 710004]  3261  131209

# %%
my_scenario.summary
# Out:
# ['time of day based properties', 'test multiple add and delete']
